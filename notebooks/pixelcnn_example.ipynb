# %% [markdown]
# # PixelCNN Example: Training and Generation
#
# This notebook demonstrates how to train a PixelCNN model and generate samples.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import sys

# Add src to path
sys.path.append(str(Path.cwd().parent / "src"))

from pixelcnn import PixelCNN, PixelCNNSampler, PixelCNNEvaluator
from pixelcnn.data import create_dataloaders
from pixelcnn.training import train_pixelcnn, set_seed
